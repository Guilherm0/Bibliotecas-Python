# %% [markdown]
# <a href="https://colab.research.google.com/github/Guilherm0/Bibliotecas-Python/blob/main/ExerciciosMatplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercícios Matplotlib

# %%
import matplotlib.pyplot as plt
valores = [15,30, 45, 10]
rotulos = ['Frogs', 'Hogs', 'Dogs', 'Logs']
explode = [0, .1, 0, 0]
cores = ['blue', 'orange', 'green', 'red']

plt.figure(figsize=(7,7))

plt.pie(
    valores,
    explode=explode,
    labels=rotulos,
    # colors=cores,
    autopct='%.1f%%',
    shadow=True,
    startangle=90,
)

plt.show()

# %%
import numpy as np
x = [1.2, 2.5, 3.3, 4.1, 4.4, 5]
y = [65, 35, 22, 50, 18, 15] #15
cores = ['red', 'green', 'yellow', 'yellow', 'green', 'red']
# cores = [0, 1, 2, 2, 1, 0]
tamanho = np.array([100, 60, 40, 80, 30, 70]) * 2
# import matplotlib
# help(matplotlib.markers)

plt.scatter(
    x, y,
    s=tamanho,
    c=cores,
    # alpha=.5,
    # marker='>'
    # cmap='Set1',
    # norm=
    # vmin=0,
    # vmax=1
    # linewidths=40
)
# plt.yticks(range(20,61,10))
plt.show()

# %%
x = ['Python', 'C++', 'Java', 'Perl', 'Scala', 'Lisp']
y = [10, 8, 6, 4, 2, 1]

plt.bar(x, y, align='center', alpha=.8, color='mediumslateblue', edgecolor='black', linewidth=.6)
plt.ylim(0,10)
plt.ylabel('Usage')
plt.title('Programing Language Usage')
plt.show()

# %%
x = ['Python', 'C++', 'Java', 'Perl', 'Scala', 'Lisp']
y = [10, 8, 6, 4, 2, 1]

plt.barh(x, y, align='center', alpha=.8, color='mediumslateblue', edgecolor='black', linewidth=.6)
plt.xlim(0,10)
plt.xlabel('Usage')
plt.title('Programing Language Usage')
plt.show()
